# %%
import numpy as np
import pandas as pd
import os
import math
import time
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Below libraries are for feature representation using sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Below libraries are for similarity matrices using sklearn
from sklearn.metrics.pairwise import cosine_similarity  
from sklearn.metrics import pairwise_distances

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /home/adon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/adon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/adon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
news_articles_1 = pd.read_json( "../News_Category_Dataset_v2.json", lines = True )
#news_articles_1 = pd.DataFrame()

news_articles_2a = pd.read_csv( "../articles1.csv" )
news_articles_2b = pd.read_csv( "../articles2.csv" )
news_articles_2c = pd.read_csv( "../articles3.csv" )
news_articles_2 = pd.concat( [news_articles_2a, news_articles_2b, news_articles_2c], ignore_index=True )
#news_articles_2 = pd.concat( [news_articles_2a], ignore_index=True )

# %%
len( news_articles_1 ) + len( news_articles_2 )
# Out:
# 343423

# %%
# empty dataframe for our training data
news_articles = pd.DataFrame( columns=[
    'id', 'category', 'headline', 'description', 
    'authors', 'publication', 'date', 'link' ] )

# %%
# clean our source data
news_articles_1.rename( columns={'short_description': 'description'}, inplace=True )
news_articles_1.insert( 0, 'id', range( 0, len( news_articles_1 ) ))
news_articles_1["publication"] = "unknown"

news_articles_2.rename( columns={'title': 'headline'}, inplace=True )
news_articles_2.rename( columns={'url': 'link'}, inplace=True )
news_articles_2.rename( columns={'content': 'description'}, inplace=True )
news_articles_2.rename( columns={'author': 'authors'}, inplace=True )
news_articles_2.drop( columns=['year', 'month'], inplace=True )
news_articles_2["category"] = "unknown"
news_articles_2['date'] = pd.to_datetime(news_articles_2['date'], format='%Y-%m-%d' )

# %%
# combine sources
news_articles = pd.concat( [news_articles_1, news_articles_2], ignore_index=True )
# reduce author name(s), publisher, and category fields to single string
news_articles['authors'] = news_articles['authors'].str.replace(" ","")
news_articles['publication'] = news_articles['publication'].str.replace(" ","")
news_articles['category'] = news_articles['category'].str.replace(" ","")
# and create combined headline and description to lemma
news_articles['text'] = news_articles['headline'] + " " + news_articles['description']

# %%
news_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343423 entries, 0 to 343422
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           343423 non-null  int64
#  1   category     343423 non-null  object
#  2   headline     343421 non-null  object
#  3   authors      327547 non-null  object
#  4   link         286412 non-null  object
#  5   description  343423 non-null  object
#  6   date         340782 non-null  datetime64[ns]
#  7   publication  343423 non-null  object
#  8   Unnamed: 0   142570 non-null  float64
#  9   text         343421 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 26.2+ MB

# %%
news_articles.head()
# Out:
#    id       category                                           headline  \
# 0   0          CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1   1  ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2   2  ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3   3  ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4   4  ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
#
#           authors                                               link  \
# 0  MelissaJeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    AndyMcDonald  https://www.huffingtonpost.com/entry/will-smit...
# 2       RonDicker  https://www.huffingtonpost.com/entry/hugh-gran...
# 3       RonDicker  https://www.huffingtonpost.com/entry/jim-carre...
# 4       RonDicker  https://www.huffingtonpost.com/entry/julianna-...
#
#                                          description       date publication  \
# 0  She left her husband. He killed their children... 2018-05-26     unknown
# 1                           Of course it has a song. 2018-05-26     unknown
# 2  The actor and his longtime girlfriend Anna Ebe... 2018-05-26     unknown
# 3  The actor gives Dems an ass-kicking for not fi... 2018-05-26     unknown
# 4  The "Dietland" actress said using the bags is ... 2018-05-26     unknown
#
#    Unnamed: 0                                               text
# 0         NaN  There Were 2 Mass Shootings In Texas Last Week...
# 1         NaN  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2         NaN  Hugh Grant Marries For The First Time At Age 5...
# 3         NaN  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4         NaN  Julianna Margulies Uses Donald Trump Poop Bags...

# %%
#news_articles = news_articles[news_articles['date'] >= pd.Timestamp(2018,1,1)]

# %%
news_articles.shape
# Out:
# (343423, 10)

# %%
#news_articles = news_articles[news_articles['text'].apply(lambda x: len(x.split())>5)]
#print("Total number of articles after removal of those with short title:", news_articles.shape[0])

# %%
news_articles.sort_values('text',inplace=True, ascending=False)
duplicated_articles_series = news_articles.duplicated('text', keep = False)
news_articles = news_articles[~duplicated_articles_series]
print("Total number of articles after removing duplicates:", news_articles.shape[0])
# Out:
# Total number of articles after removing duplicates: 342290

# %%
news_articles.index = range(news_articles.shape[0])

# %%
# Adding a new column containing both day of the week and month, it will be required later while recommending based on day of the week and month
news_articles["day and month"] = news_articles["date"].dt.strftime("%a") + "_" + news_articles["date"].dt.strftime("%b")

# %%
news_articles_temp = news_articles.copy()

# %%
stop_words = set(stopwords.words('english'))

# %%
for i in range(len(news_articles_temp["text"])):
    string = ""
    for word in news_articles_temp["text"][i].split():
        #print(word)
        word = ("".join(e for e in word if e.isalnum()))
        word = word.lower()
        if not word in stop_words:
          string += word + " "  
    if(i%10000==0):
      print(i)           # To track number of records processed
    news_articles_temp.at[i,"text"] = string.strip()
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000

# %%
lemmatizer = WordNetLemmatizer()

# %%
#nltk.download('omw-1.4')

# %%
for i in range(len(news_articles_temp["text"])):
    string = ""
    for w in word_tokenize(news_articles_temp["text"][i]):
        string += lemmatizer.lemmatize(w,pos = "v") + " "
    news_articles_temp.at[i, "text"] = string.strip()
    if(i%10000==0):
        print(i)           # To track number of records processed
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000

# %% [markdown]
# # TF-IDF method

# %%
tfidf_text_vectorizer = TfidfVectorizer(min_df = 0)
tfidf_text_features = tfidf_text_vectorizer.fit_transform(news_articles_temp['text'])

# %%
def tfidf_based_model(row_index, num_similar_items=6):
    couple_dist = pairwise_distances(tfidf_text_features,tfidf_text_features[row_index])
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df = pd.DataFrame({'publish_date': news_articles['date'][indices].values,
               'text':news_articles['text'][indices].values,
                'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    #print("="*30,"Queried article details","="*30)
    print('text : ',news_articles['text'][indices[0]])
    #print("\n","="*25,"Recommended articles : ","="*23)
    
    #return df.iloc[1:,1]
    return df.iloc[1:,]
tfidf_based_model(2)
# Out:
# text :  “We’re going out in a blaze of glory” — why NASA is crashing a 20-year-old spacecraft into Saturn  In the 20 years it’s been in space, the Cassini spacecraft has seen storms on Saturn’s surface, sent a probe down to the planet’s moon Titan, and shown us the eerie beauty of the gas giant’s hexagonal north pole. As it is rapidly running out of fuel, it’s been given one last mission before it goes offline in September: to solve the mystery of the planet’s rings.    “We’re uncertain by quite a large margin about how much stuff is really there [in the rings],” Preston Dyches, a NASA spokesperson for the Cassini mission, said in December. “That has major implication for how they formed and how old they are. That’s still one of the biggest mysteries of Saturn  —   how did it get these rings  —   which tells us things about how planets form and how planets form around other stars. ”  Studying Saturn’s rings helps scientists understand how planets and solar systems form. It’s likely the Earth and all the planets in our solar system formed out of a ring of gas and debris around the sun.  To solve the mystery, on April 26, Cassini will make a perilous and unprecedented maneuver, diving into the space between the planet and its rings for the first time. Cassini’s “grand finale,” as NASA is calling it, might be its most impressive feat to date.     Cassini will spend its final months getting an unprecedented look at Saturn’s rings On April 26, after a brief flyby, Cassini will change its orbit and dive into the    space between Saturn and its inner rings. Cassini has never been to this region before. No spacecraft has.     This is what that dive will look like from Cassini’s perspective. It will repeat this 22 times.                                     When Cassini is in the inner rings, it will finally be able to take the measurements that will aid in calculations to determine the mass of the rings.     As Dyches explains it, NASA already knows the mass of Saturn plus its rings. But it’s difficult to subtract out the mass of the planet’s rings from those estimates. While Cassini is in between the planet and its rings, it can take measurements of Saturn’s gravity and mass without factoring in the rings. That measurement can then determine the mass of the rings.              Cassini’s grand finale On September 15, 2017, Cassini will end its mission. But it will have one more trick up its sleeve. Having completed its ring passes, it will plunge into Saturn’s atmosphere  —   a place no spacecraft has been before. It’s a suicide mission: Cassini will try to send Earth some last bits of data before it breaks apart and burns, joining Saturn’s atmosphere for eternity.  “We’re going out in a blaze of glory,” Dyches says. Literally: Below, NASA animates what the crash will likely look like.     The death dive isn’t just for fireworks. It’s necessary. If Cassini doesn’t crash into Saturn, it runs the risk of potentially contaminating one of Saturn’s moons with debris and microbes from Earth. “Plunging it into Saturn . .. is the safest” option, Dyches says.  Cassini’s dramatic finale is also a last chance to squeeze some more insights out of the    spacecraft. As Cassini descends into the atmosphere, “several of the instruments will be on,” including the mass spectrometer, Dyches says. This instrument essentially can “sniff” the atmosphere and determine the chemical compounds it’s composed of.  “Nothing has ever gone into Saturn before,” he says. “We know that its atmosphere, from telescopes from the outside, [is] mostly hydrogen and helium  —   but there might be a sprinkling of other ingredients, heavier elements. We also don’t know how that composition varies with altitude. ”  Meanwhile, with its last ounces of strength, Cassini will try to keep its antenna pointed toward the Earth for data transmission. But “the thrusters weren’t designed for this,” Dyches says. We won’t know how much information we’ll get until it happens.  ”This planned ...
#   publish_date                                               text  \
# 1   2017-04-26  The Cassini spacecraft’s dive in between Satur...
# 2   2017-04-05  Cassini spacecraft to dive inside Saturn’s rin...
# 3   2017-04-26  Cassini spacecraft prepares dive into Saturn’s...
# 4   2017-04-27  U.S. spacecraft shares first view from inside ...
# 5   2017-04-13  Watch NASA’s latest discovery about “ocean wor...
#
#    Euclidean similarity with the queried article
# 1                                       0.475123
# 2                                       0.698914
# 3                                       0.717112
# 4                                       0.720067
# 5                                       0.723536

# %% [markdown]
# # Weighted similarity based on category, publish day and author

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
category_onehot_encoded = OneHotEncoder().fit_transform(np.array(news_articles_temp["category"]).reshape(-1,1))

# %%
publishingday_onehot_encoded = OneHotEncoder().fit_transform(np.array(news_articles_temp["day and month"]).reshape(-1,1))

# %%
authors_onehot_encoded = OneHotEncoder().fit_transform(np.array(news_articles_temp["authors"]).reshape(-1,1))

# %%
def avg_TFIDF_with_category_authors_and_publshing_day(row_index, num_similar_items, w1,w2,w3,w4): #headline_preference = True, category_preference = False):
    w2v_dist  = pairwise_distances(tfidf_text_features,tfidf_text_features[row_index].reshape(1,-1))
    category_dist = pairwise_distances(category_onehot_encoded, category_onehot_encoded[row_index]) + 1
    authors_dist = pairwise_distances(authors_onehot_encoded, authors_onehot_encoded[row_index]) + 1
    publishingday_dist = pairwise_distances(publishingday_onehot_encoded, publishingday_onehot_encoded[row_index]) + 1
    weighted_couple_dist   = (w1 * w2v_dist +  w2 * category_dist + w3 * authors_dist + w4 * publishingday_dist)/float(w1 + w2 + w3 + w4)
    indices = np.argsort(weighted_couple_dist.flatten())[0:num_similar_items].tolist()
    df = pd.DataFrame({'publish_date': news_articles['date'][indices].values,
                'headline_text':news_articles['headline'][indices].values,
                'Weighted Euclidean similarity with the queried article': weighted_couple_dist[indices].ravel(),
                'Word2Vec based Euclidean similarity': w2v_dist[indices].ravel(),
                'Category based Euclidean similarity': category_dist[indices].ravel(),
                'Authors based Euclidean similarity': authors_dist[indices].ravel(),   
                'Publishing day based Euclidean similarity': publishingday_dist[indices].ravel(), 
                'Categoty': news_articles['category'][indices].values,
                'Authors': news_articles['authors'][indices].values,
                'Day and month': news_articles['day and month'][indices].values})
    print("="*30,"Queried article details","="*30)
    print('headline : ',news_articles['headline'][indices[0]])
    print('Categoty : ', news_articles['category'][indices[0]])
    print('Authors : ', news_articles['authors'][indices[0]])
    print('Day and month : ', news_articles['day and month'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    #return df.iloc[1:,[1,7,8,9]]
    return df.iloc[1:, ]

# %%
news_articles.shape
# Out:
# (342290, 11)

# %%
#interesting results...
avg_TFIDF_with_category_authors_and_publshing_day(52,10,0.5,0.2,0.2,0.1)
# Out:
# ============================== Queried article details ==============================
# headline :  ’Zen And The Art of Motorcycle Maintenance’ Author Robert M. Pirsig Dies At 88
# Categoty :  unknown
# Authors :  LaurelWamsley
# Day and month :  Mon_Apr
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2017-04-24  Robert Pirsig: Zen and the Art of Motorcycle M...
# 2   2017-04-25                    Author Robert Pirsig dies at 88
# 3   2017-02-21  Who’s Who In The Race For DNC Chair — And Thei...
# 4   2017-06-12  One Year After Pulse Shooting, Orlando Honors ...
# 5   2017-05-15  Like Most White House Kids, Barron Trump Will ...
# 6   2017-05-27  White Supremacist Charged With Killing 2 In Po...
# 7   2017-03-31  Serial Killer Dubbed ’Angel Of Death’ Dies Aft...
# 8   2016-12-29               The Top Stories On NPR.org This Year
# 9   2017-04-26  In Surprise TED Talk, Pope Francis Asks The Po...
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.128348
# 2                                           1.317602
# 3                                           1.329411
# 4                                           1.331638
# 5                                           1.333259
# 6                                           1.333388
# 7                                           1.333406
# 8                                           1.334241
# 9                                           1.334797
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             0.691010                                  1.0
# 2                             0.786677                                  1.0
# 3                             1.375980                                  1.0
# 4                             1.380434                                  1.0
# 5                             1.383675                                  1.0
# 6                             1.383934                                  1.0
# 7                             1.383969                                  1.0
# 8                             1.385639                                  1.0
# 9                             1.386751                                  1.0
#
#    Authors based Euclidean similarity  \
# 1                            2.414214
# 2                            2.414214
# 3                            1.000000
# 4                            1.000000
# 5                            1.000000
# 6                            1.000000
# 7                            1.000000
# 8                            1.000000
# 9                            1.000000
#
#    Publishing day based Euclidean similarity Categoty          Authors  \
# 1                                   1.000000  unknown              NaN
# 2                                   2.414214  unknown  AssociatedPress
# 3                                   2.414214  unknown    LaurelWamsley
# 4                                   2.414214  unknown    LaurelWamsley
# 5                                   2.414214  unknown    LaurelWamsley
# 6                                   2.414214  unknown    LaurelWamsley
# 7                                   2.414214  unknown    LaurelWamsley
# 8                                   2.414214  unknown    LaurelWamsley
# 9                                   2.414214  unknown    LaurelWamsley
#
#   Day and month
# 1       Mon_Apr
# 2       Tue_Apr
# 3       Tue_Feb
# 4       Mon_Jun
# 5       Mon_May
# 6       Sat_May
# 7       Fri_Mar
# 8       Thu_Dec
# 9       Wed_Apr

# %%
avg_TFIDF_with_category_authors_and_publshing_day(52,5,0.6,0.2,0.1,0.1)
# Out:
# ============================== Queried article details ==============================
# headline :  ’Zen And The Art of Motorcycle Maintenance’ Author Robert M. Pirsig Dies At 88
# Categoty :  unknown
# Authors :  LaurelWamsley
# Day and month :  Mon_Apr
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2017-04-24  Robert Pirsig: Zen and the Art of Motorcycle M...
# 2   2017-04-25                    Author Robert Pirsig dies at 88
# 3          NaT                               And There We Have it
# 4   2017-04-03  Documentarian Says ’Anarchist Cookbook’ Author...
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           0.956027
# 2                                           1.154849
# 3                                           1.282843
# 4                                           1.350916
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             0.691010                                  1.0
# 2                             0.786677                                  1.0
# 3                             1.000000                                  1.0
# 4                             1.349158                                  1.0
#
#    Authors based Euclidean similarity  \
# 1                            2.414214
# 2                            2.414214
# 3                            2.414214
# 4                            2.414214
#
#    Publishing day based Euclidean similarity Categoty          Authors  \
# 1                                   1.000000  unknown              NaN
# 2                                   2.414214  unknown  AssociatedPress
# 3                                   2.414214  unknown     JoshMarshall
# 4                                   1.000000  unknown     KellyMcEvers
#
#   Day and month
# 1       Mon_Apr
# 2       Tue_Apr
# 3           NaN
# 4       Mon_Apr

# %%
# this one performs particularly well
avg_TFIDF_with_category_authors_and_publshing_day(56001,25,0.6,0.2,0.1,0.1)
# Out:
# ============================== Queried article details ==============================
# headline :  Thousands of Flint residents could lose their homes over unpaid water bills
# Categoty :  unknown
# Authors :  MarkAbadi
# Day and month :  Thu_May
#
#  ========================= Recommended articles :  =======================
#    publish_date                                      headline_text  \
# 1    2017-05-18   Flint Residents Win Battle Over Losing Their ...
# 2    2016-02-04   Unpaid Water Bills In Flint Could Hinder Repairs
# 3    2016-05-05  Obama sips Flint water, urges children be test...
# 4    2017-02-28  Flint residents must start paying for water th...
# 5    2017-03-01  Michigan Ends Water Subsidies To Flint Despite...
# 6    2017-01-24  Flint water falls below federal lead limits, b...
# 7    2016-04-20  Lead-Laced Water In Flint: A Step-By-Step Look...
# 8    2016-12-20                 The Flint water crisis is not over
# 9    2016-02-15                  The Flint water crisis, explained
# 10   2016-05-04  Watch: President Obama speaks at Flint, Michig...
# 11   2017-04-18  3 Years After Ill-Fated Switch, Flint Mayor Re...
# 12   2016-02-06  For the people of Flint, hope — and clean wate...
# 13   2016-05-05  The EPA’s lead-in-water rule has been faulted ...
# 14   2016-02-17   Flint Residents Had Highest Water Bills In Th...
# 15   2016-08-14  Federal State Of Emergency Over Lead-Laced Wat...
# 16   2017-03-28  Michigan Allots $87 Million to Replace Flint’s...
# 17   2016-11-12  Bottled water must be delivered to Flint resid...
# 18   2016-01-20  ‘I let you down.’ Michigan governor apologizes...
# 19   2016-12-14  A Year Later, Unfiltered Flint Tap Water Is St...
# 20   2016-01-21  Political fallout from Flint, Michigan water c...
# 21   2016-04-15  I’m an environmental reporter from Flint. Even...
# 22   2016-10-22  ‘If I could afford to leave, I would.’ In Flin...
# 23   2016-01-21  Flint Mayor: ’Politics And Profit’ Perpetuated...
# 24   2016-01-28  Flint water crisis: Michigan made sure state e...
#
#     Weighted Euclidean similarity with the queried article  \
# 1                                            0.988426
# 2                                            1.104222
# 3                                            1.108531
# 4                                            1.134226
# 5                                            1.142510
# 6                                            1.147299
# 7                                            1.170705
# 8                                            1.183970
# 9                                            1.185117
# 10                                           1.187538
# 11                                           1.192435
# 12                                           1.192847
# 13                                           1.194082
# 14                                           1.199298
# 15                                           1.199639
# 16                                           1.199673
# 17                                           1.203559
# 18                                           1.209684
# 19                                           1.210659
# 20                                           1.213134
# 21                                           1.218731
# 22                                           1.224339
# 23                                           1.224791
# 24                                           1.226138
#
#     Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                              0.745007                                  1.0
# 2                              0.702298                                  1.0
# 3                              0.945182                                  1.0
# 4                              0.752306                                  1.0
# 5                              0.766112                                  1.0
# 6                              0.774093                                  1.0
# 7                              0.813104                                  1.0
# 8                              0.835213                                  1.0
# 9                              0.837124                                  1.0
# 10                             0.841159                                  1.0
# 11                             0.849320                                  1.0
# 12                             0.850008                                  1.0
# 13                             1.087769                                  1.0
# 14                             0.860759                                  1.0
# 15                             0.861327                                  1.0
# 16                             0.861384                                  1.0
# 17                             0.867861                                  1.0
# 18                             0.878069                                  1.0
# 19                             0.879694                                  1.0
# 20                             0.883819                                  1.0
# 21                             0.893147                                  1.0
# 22                             0.902494                                  1.0
# 23                             0.903247                                  1.0
# 24                             0.905492                                  1.0
#
#     Authors based Euclidean similarity  \
# 1                             2.414214
# 2                             2.414214
# 3                             2.414214
# 4                             2.414214
# 5                             2.414214
# 6                             2.414214
# 7                             2.414214
# 8                             2.414214
# 9                             2.414214
# 10                            2.414214
# 11                            2.414214
# 12                            2.414214
# 13                            2.414214
# 14                            2.414214
# 15                            2.414214
# 16                            2.414214
# 17                            2.414214
# 18                            2.414214
# 19                            2.414214
# 20                            2.414214
# 21                            2.414214
# 22                            2.414214
# 23                            2.414214
# 24                            2.414214
#
#     Publishing day based Euclidean similarity Categoty  \
# 1                                    1.000000  unknown
# 2                                    2.414214  unknown
# 3                                    1.000000  unknown
# 4                                    2.414214  unknown
# 5                                    2.414214  unknown
# 6                                    2.414214  unknown
# 7                                    2.414214  unknown
# 8                                    2.414214  unknown
# 9                                    2.414214  unknown
# 10                                   2.414214  unknown
# 11                                   2.414214  unknown
# 12                                   2.414214  unknown
# 13                                   1.000000  unknown
# 14                                   2.414214  unknown
# 15                                   2.414214  unknown
# 16                                   2.414214  unknown
# 17                                   2.414214  unknown
# 18                                   2.414214  unknown
# 19                                   2.414214  unknown
# 20                                   2.414214  unknown
# 21                                   2.414214  unknown
# 22                                   2.414214  unknown
# 23                                   2.414214  unknown
# 24                                   2.414214  unknown
#
#                        Authors Day and month
# 1                 BriannaSacks       Thu_May
# 2                 SteveCarmody       Thu_Feb
# 3               TimothyGardner       Thu_May
# 4                  BradyDennis       Tue_Feb
# 5                MerritKennedy       Wed_Mar
# 6                   MarkBerman       Tue_Jan
# 7                MerritKennedy       Wed_Apr
# 8                  ConnorCoyne       Tue_Dec
# 9                  LibbyNelson       Mon_Feb
# 10                 GermanLopez       Wed_May
# 11               LaurelWamsley       Tue_Apr
# 12              LennyBernstein       Sat_Feb
# 13                 BradyDennis       Thu_May
# 14              TamerraGriffin       Wed_Feb
# 15               MerritKennedy       Sun_Aug
# 16                 JulieBosman       Tue_Mar
# 17                  RyanFelton       Sat_Nov
# 18                  MarkBerman       Wed_Jan
# 19                SteveCarmody       Wed_Dec
# 20  TimothyGardnerandJeffMason       Thu_Jan
# 21                 TaliaBuford       Fri_Apr
# 22                 BradyDennis       Sat_Oct
# 23               MerritKennedy       Thu_Jan
# 24                 LibbyNelson       Thu_Jan

# %%
# but we dilute it quickly with the subject i think
avg_TFIDF_with_category_authors_and_publshing_day(56001,5,0.3,0.3,0.2,0.1)
# Out:
# ============================== Queried article details ==============================
# headline :  Thousands of Flint residents could lose their homes over unpaid water bills
# Categoty :  unknown
# Authors :  MarkAbadi
# Day and month :  Thu_May
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2017-05-25  Government officials in the UK are fuming over...
# 2   2017-05-18   Flint Residents Win Battle Over Losing Their ...
# 3   2017-01-06  3 more states are proposing ’bathroom bills’ t...
# 4   2016-05-14  Here are the 10 most and least popular governo...
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.132206
# 2                                           1.229272
# 3                                           1.256705
# 4                                           1.261974
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             1.396619                                  1.0
# 2                             0.745007                                  1.0
# 3                             1.298711                                  1.0
# 4                             1.314519                                  1.0
#
#    Authors based Euclidean similarity  \
# 1                            1.000000
# 2                            2.414214
# 3                            1.000000
# 4                            1.000000
#
#    Publishing day based Euclidean similarity Categoty       Authors  \
# 1                                   1.000000  unknown     MarkAbadi
# 2                                   1.000000  unknown  BriannaSacks
# 3                                   2.414214  unknown     MarkAbadi
# 4                                   2.414214  unknown     MarkAbadi
#
#   Day and month
# 1       Thu_May
# 2       Thu_May
# 3       Fri_Jan
# 4       Sat_May

# %%
# same with the authors ... it quickly poisons
avg_TFIDF_with_category_authors_and_publshing_day(56001,10,0.59,0.005,0.3,0.005)
# Out:
# ============================== Queried article details ==============================
# headline :  Thousands of Flint residents could lose their homes over unpaid water bills
# Categoty :  unknown
# Authors :  MarkAbadi
# Day and month :  Thu_May
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2017-01-06  3 more states are proposing ’bathroom bills’ t...
# 2   2016-05-14  Here are the 10 most and least popular governo...
# 3   2017-03-09  Texas’ controversial ’bathroom bill’ cleared i...
# 4   2017-03-31  ’This is a bait and switch’: Liberal groups ar...
# 5   2016-12-22  North Carolina Republicans issued a bizarre st...
# 6   2016-06-17  The US dropped 67 nuclear bombs on this tiny i...
# 7   2017-03-31  North Carolina just repealed its notorious ’ba...
# 8   2016-12-21  North Carolina’s embattled departing governor ...
# 9   2016-12-08  People in North Carolina are freaking out over...
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.203678
# 2                                           1.214041
# 3                                           1.230430
# 4                                           1.240191
# 5                                           1.247233
# 6                                           1.247895
# 7                                           1.249830
# 8                                           1.251620
# 9                                           1.253478
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             1.298711                                  1.0
# 2                             1.314519                                  1.0
# 3                             1.339518                                  1.0
# 4                             1.354409                                  1.0
# 5                             1.365151                                  1.0
# 6                             1.366160                                  1.0
# 7                             1.369111                                  1.0
# 8                             1.371843                                  1.0
# 9                             1.374677                                  1.0
#
#    Authors based Euclidean similarity  \
# 1                                 1.0
# 2                                 1.0
# 3                                 1.0
# 4                                 1.0
# 5                                 1.0
# 6                                 1.0
# 7                                 1.0
# 8                                 1.0
# 9                                 1.0
#
#    Publishing day based Euclidean similarity Categoty    Authors Day and month
# 1                                   2.414214  unknown  MarkAbadi       Fri_Jan
# 2                                   2.414214  unknown  MarkAbadi       Sat_May
# 3                                   2.414214  unknown  MarkAbadi       Thu_Mar
# 4                                   2.414214  unknown  MarkAbadi       Fri_Mar
# 5                                   2.414214  unknown  MarkAbadi       Thu_Dec
# 6                                   2.414214  unknown  MarkAbadi       Fri_Jun
# 7                                   2.414214  unknown  MarkAbadi       Fri_Mar
# 8                                   2.414214  unknown  MarkAbadi       Wed_Dec
# 9                                   2.414214  unknown  MarkAbadi       Thu_Dec

# %%
# but around .2 the authors work nicely here
avg_TFIDF_with_category_authors_and_publshing_day(56001,10,0.69,0.005,0.2,0.005)
# Out:
# ============================== Queried article details ==============================
# headline :  Thousands of Flint residents could lose their homes over unpaid water bills
# Categoty :  unknown
# Authors :  MarkAbadi
# Day and month :  Thu_May
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2016-02-04   Unpaid Water Bills In Flint Could Hinder Repairs
# 2   2017-05-18   Flint Residents Win Battle Over Losing Their ...
# 3   2017-02-28  Flint residents must start paying for water th...
# 4   2017-03-01  Michigan Ends Water Subsidies To Flint Despite...
# 5   2017-01-24  Flint water falls below federal lead limits, b...
# 6   2016-04-20  Lead-Laced Water In Flint: A Step-By-Step Look...
# 7   2017-05-03  Some Flint Residents Could Face Foreclosure Ov...
# 8   2016-12-20                 The Flint water crisis is not over
# 9   2016-02-15                  The Flint water crisis, explained
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.093888
# 2                                           1.118775
# 3                                           1.132227
# 4                                           1.142813
# 5                                           1.148931
# 6                                           1.178839
# 7                                           1.194253
# 8                                           1.195789
# 9                                           1.197255
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             0.702298                             1.000000
# 2                             0.745007                             1.000000
# 3                             0.752306                             1.000000
# 4                             0.766112                             1.000000
# 5                             0.774093                             1.000000
# 6                             0.813104                             1.000000
# 7                             0.822960                             2.414214
# 8                             0.835213                             1.000000
# 9                             0.837124                             1.000000
#
#    Authors based Euclidean similarity  \
# 1                            2.414214
# 2                            2.414214
# 3                            2.414214
# 4                            2.414214
# 5                            2.414214
# 6                            2.414214
# 7                            2.414214
# 8                            2.414214
# 9                            2.414214
#
#    Publishing day based Euclidean similarity  Categoty        Authors  \
# 1                                   2.414214   unknown   SteveCarmody
# 2                                   1.000000   unknown   BriannaSacks
# 3                                   2.414214   unknown    BradyDennis
# 4                                   2.414214   unknown  MerritKennedy
# 5                                   2.414214   unknown     MarkBerman
# 6                                   2.414214   unknown  MerritKennedy
# 7                                   2.414214  POLITICS  ArthurDelaney
# 8                                   2.414214   unknown    ConnorCoyne
# 9                                   2.414214   unknown    LibbyNelson
#
#   Day and month
# 1       Thu_Feb
# 2       Thu_May
# 3       Tue_Feb
# 4       Wed_Mar
# 5       Tue_Jan
# 6       Wed_Apr
# 7       Wed_May
# 8       Tue_Dec
# 9       Mon_Feb

# %%
# looking really good
avg_TFIDF_with_category_authors_and_publshing_day(256001,10,0.69,0.005,0.2,0.005)
# Out:
# ============================== Queried article details ==============================
# headline :  Divorce, Illness and Compassion
# Categoty :  DIVORCE
# Authors :  RobinAmosKahn,Contributor
# Writer,Speaker,LeadCoachatOwntheRoom
# Day and month :  Thu_Jun
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2012-10-01                                 The Joy of Divorce
# 2   2014-02-20                        Divorce: "You Will Survive"
# 3   2013-08-26  Thank You, G-D, for This Hellish Divorce and A...
# 4   2013-11-07                     How Pema Chodron Saved My Life
# 5   2013-06-11                  Out of the Nest and Into the Fire
# 6   2013-08-14                                Write for Your Life
# 7   2014-04-09                          The Freedom of Letting Go
# 8   2013-10-04                             Men, Divorce, and Love
# 9   2013-07-12                              Welcome to Crazy Time
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.252620
# 2                                           1.270997
# 3                                           1.276467
# 4                                           1.280184
# 5                                           1.290292
# 6                                           1.290964
# 7                                           1.291731
# 8                                           1.299527
# 9                                           1.302892
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             1.319257                             1.000000
# 2                             1.343226                             1.000000
# 3                             1.350361                             1.000000
# 4                             1.344962                             2.414214
# 5                             1.368394                             1.000000
# 6                             1.369270                             1.000000
# 7                             1.370270                             1.000000
# 8                             1.380439                             1.000000
# 9                             1.384829                             1.000000
#
#    Authors based Euclidean similarity  \
# 1                                 1.0
# 2                                 1.0
# 3                                 1.0
# 4                                 1.0
# 5                                 1.0
# 6                                 1.0
# 7                                 1.0
# 8                                 1.0
# 9                                 1.0
#
#    Publishing day based Euclidean similarity  Categoty  \
# 1                                   2.414214   DIVORCE
# 2                                   2.414214   DIVORCE
# 3                                   2.414214   DIVORCE
# 4                                   2.414214  WELLNESS
# 5                                   2.414214   DIVORCE
# 6                                   2.414214   DIVORCE
# 7                                   2.414214   DIVORCE
# 8                                   2.414214   DIVORCE
# 9                                   2.414214   DIVORCE
#
#                                              Authors Day and month
# 1  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Mon_Oct
# 2  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Thu_Feb
# 3  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Mon_Aug
# 4  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Thu_Nov
# 5  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Tue_Jun
# 6  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Wed_Aug
# 7  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Wed_Apr
# 8  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Fri_Oct
# 9  RobinAmosKahn,Contributor\nWriter,Speaker,Lead...       Fri_Jul

# %%
# this one doesn't perform well
avg_TFIDF_with_category_authors_and_publshing_day(156007,10,0.69,0.005,0.2,0.005)
# Out:
# ============================== Queried article details ==============================
# headline :  Minister Set Fire To Own Home, Then Lied To FBI About Staged Hate Crime: Prosecutors
# Categoty :  CRIME
# Authors :  RichmondTimes-Dispatch,RichmondTimes-Dispatch
# Day and month :  Sat_Nov
#
#  ========================= Recommended articles :  =======================
#   publish_date         headline_text  \
# 1   2015-05-24           No, No, No!
# 2          NaT  And There We Have it
# 3   2014-07-02                  Over
# 4   2014-06-05         Because I Can
# 5   2015-04-05           B Is for...
# 6   2015-10-11                 Once.
# 7   2016-06-05               L O V E
# 8   2014-11-25             As We Are
# 9   2015-04-29     WHO Are You Now ?
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.329983
# 2                                           1.329983
# 3                                           1.329983
# 4                                           1.329983
# 5                                           1.329983
# 6                                           1.329983
# 7                                           1.329983
# 8                                           1.329983
# 9                                           1.329983
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                                  1.0                             2.414214
# 2                                  1.0                             2.414214
# 3                                  1.0                             2.414214
# 4                                  1.0                             2.414214
# 5                                  1.0                             2.414214
# 6                                  1.0                             2.414214
# 7                                  1.0                             2.414214
# 8                                  1.0                             2.414214
# 9                                  1.0                             2.414214
#
#    Authors based Euclidean similarity  \
# 1                            2.414214
# 2                            2.414214
# 3                            2.414214
# 4                            2.414214
# 5                            2.414214
# 6                            2.414214
# 7                            2.414214
# 8                            2.414214
# 9                            2.414214
#
#    Publishing day based Euclidean similarity       Categoty  \
# 1                                   2.414214         COMEDY
# 2                                   2.414214        unknown
# 3                                   2.414214          FIFTY
# 4                                   2.414214  HEALTHYLIVING
# 5                                   2.414214         COMEDY
# 6                                   2.414214         COMEDY
# 7                                   2.414214  HEALTHYLIVING
# 8                                   2.414214  HEALTHYLIVING
# 9                                   2.414214  ENTERTAINMENT
#
#                                              Authors Day and month
# 1     MarciaLiss,Contributor(Almost)FamousCartoonist       Sun_May
# 2                                       JoshMarshall           NaN
# 3  LisaK.Brown,ContributorFreelancewriterandbemus...       Wed_Jul
# 4  JudithGreenberg,Ph.D.,ContributorGallatinSchoo...       Thu_Jun
# 5     MarciaLiss,Contributor(Almost)FamousCartoonist       Sun_Apr
# 6     MarciaLiss,Contributor(Almost)FamousCartoonist       Sun_Oct
# 7  SOEMOELWIN,ContributorArtistandExplorer,always...       Sun_Jun
# 8  FrancescaMilliken,ContributorWritesaboutbeingh...       Tue_Nov
# 9  Rev.PeterE.Bauer,ContributorUnitedChurchofChri...       Wed_Apr

# %%
# not bad ... some repeat recommendations, but that is to be expected
avg_TFIDF_with_category_authors_and_publshing_day(330001,10,0.69,0.005,0.2,0.005)
# Out:
# ============================== Queried article details ==============================
# headline :  11 Times Latinos Stole The Show In 2015
# Categoty :  LATINOVOICES
# Authors :  CarolinaMorenoandTanishaLoveRamirez
# Day and month :  Fri_Dec
#
#  ========================= Recommended articles :  =======================
#   publish_date                                      headline_text  \
# 1   2016-12-28  13 Times Latinos Filled Us With Hope And Pride...
# 2   2015-09-10  19 Non-Latino Celebrities Show Off Their Spani...
# 3   2015-05-24                                        No, No, No!
# 4          NaT                               And There We Have it
# 5   2014-11-25                                          As We Are
# 6   2016-06-05                                            L O V E
# 7   2014-07-02                                               Over
# 8   2015-04-05                                        B Is for...
# 9   2014-06-05                                      Because I Can
#
#    Weighted Euclidean similarity with the queried article  \
# 1                                           1.107596
# 2                                           1.314810
# 3                                           1.329983
# 4                                           1.329983
# 5                                           1.329983
# 6                                           1.329983
# 7                                           1.329983
# 8                                           1.329983
# 9                                           1.329983
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1                             1.130094                             1.000000
# 2                             1.400374                             1.000000
# 3                             1.000000                             2.414214
# 4                             1.000000                             2.414214
# 5                             1.000000                             2.414214
# 6                             1.000000                             2.414214
# 7                             1.000000                             2.414214
# 8                             1.000000                             2.414214
# 9                             1.000000                             2.414214
#
#    Authors based Euclidean similarity  \
# 1                            1.000000
# 2                            1.000000
# 3                            2.414214
# 4                            2.414214
# 5                            2.414214
# 6                            2.414214
# 7                            2.414214
# 8                            2.414214
# 9                            2.414214
#
#    Publishing day based Euclidean similarity       Categoty  \
# 1                                   2.414214   LATINOVOICES
# 2                                   2.414214   LATINOVOICES
# 3                                   2.414214         COMEDY
# 4                                   2.414214        unknown
# 5                                   2.414214  HEALTHYLIVING
# 6                                   2.414214  HEALTHYLIVING
# 7                                   2.414214          FIFTY
# 8                                   2.414214         COMEDY
# 9                                   2.414214  HEALTHYLIVING
#
#                                              Authors Day and month
# 1                CarolinaMorenoandTanishaLoveRamirez       Wed_Dec
# 2                CarolinaMorenoandTanishaLoveRamirez       Thu_Sep
# 3     MarciaLiss,Contributor(Almost)FamousCartoonist       Sun_May
# 4                                       JoshMarshall           NaN
# 5  FrancescaMilliken,ContributorWritesaboutbeingh...       Tue_Nov
# 6  SOEMOELWIN,ContributorArtistandExplorer,always...       Sun_Jun
# 7  LisaK.Brown,ContributorFreelancewriterandbemus...       Wed_Jul
# 8     MarciaLiss,Contributor(Almost)FamousCartoonist       Sun_Apr
# 9  JudithGreenberg,Ph.D.,ContributorGallatinSchoo...       Thu_Jun
